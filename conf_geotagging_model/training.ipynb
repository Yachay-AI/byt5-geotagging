# %%
#!pip install transformers

# %%
from aux_files.learner import Learner

# %%
# all arguments in args_parser.dafault_args
args = {
    'data_dir': './data/data_sample',
    'save_prefix': './models/conf_geo_model',
    'arch': 'char_lstm',
    'split_uids': True,
    'batch_size': 128,
    'loss': 'l1',
    'optimizer': 'adamw',
    'metric': 'gc_distance',
    'scheduler': 'constant',
    'lr': 5e-4,
    'num_epoch': 25,
    'conf_estim': True,
    'confidence_validation_criterion': True
}

# %%
conf_geo_learner = Learner(args)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
conf_geo_learner.train()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# val_mean_distance: 5199.14423828125
# val_median_distance: 5440.033935546875
# top 2% - test mean: 0.0
# top 2% - test median: 0.0
# top 5% - test mean: 0.0
# top 5% - test median: 0.0
# top 10% - test mean: 5441.669921875
# top 10% - test median: 5441.669921875
# top 25% - test mean: 5441.31787109375
# top 25% - test median: 5441.31787109375
# top 50% - test mean: 5320.14638671875
# top 50% - test median: 5440.9658203125
# top 100% - test mean: 5199.14423828125
# top 100% - test median: 5440.033935546875
#
# using top 25% - val mean: 5441.31787109375
# using top 25% - val median: 5441.31787109375
#
# saving ./models/conf_geo_model.pt @ epoch 0; mean distance: 5441.317871; median distance: 5441.317871
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p36/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...
